# %% [markdown]
# ### `IterativeImputer` 하이퍼파라미터
# - estimator : 누락 값을 추정하기 위한 사용.
#     - 기본값 = BayesianRidge()
#     - LinearRegression, DecisionTreeRegressor, KNeighborsRegressor 등 다른 회귀추정기로 변경 가능
# - max_iter : 최대 반복 횟수. 누락 값을 추정하는 최대 사이클 수
#     - 기본값 = 10
# - random_state : 난수 생성기의 시드 값을 설정. 동일한 결과 재현할 때 유용
# - initial_strategy : 누락 값을 초기에 대치할 전략
#     - 기본값 = 'mean'
#     - 'mean', 'median', 'most_frequent', 'constant' 중 하나를 선택 가능
# - imputation_order : 특성을 대치하는 순서를 결정
#     - 기본값 = 'ascending'
#     - 'ascending', 'descending', 'roman', 'arabic', 'random' 중 선택
# - skip_complete : True로 설정 시, 완전한 케이스(누락 값 없는 경우)를 계산에서 제외.
#     - 기본값 = False
# - add_indicator : 누락된 특성에 대한 추가적 지표(누락 값이 있음을 나타내는 이진변수)를 추가할지 여부를 결정
#     - 기본값 = False
# - tol : 반복을 멈출 임계값. 이전과 현재 반복 사이의 평균제곱차이가 이 값보다 작을 경우 반복 중지
#     - 기본값 = 1e-3
# - n_nearest_features : 각 특성을 대치할 때 고려할 다른 특성의 수.
#     - 기본값 = None
#     - None으로 설정하면 모든 특성이 사용됨
# - verbose : 실행 중 출력 메시지의 양을 제어. 값이 클수록 더 많은 메시지 출력
#     - 기본값 = 0
# - sample_posterior : True로 설정 시, BausianRidge 추정기를 사용할 때 샘플링을 통해 후방 분포에서 값 추정
#     - 기본값 = False

# %% [markdown]
# ## `SimpleImputer` 하이퍼파라미터:
#
# 1. **missing_values**: 누락된 값을 나타내는 placeholder입니다. 기본값은 `np.nan`입니다. 숫자나 NaN 외에도 다른 표현을 사용할 수 있습니다.
#
# 2. **strategy**: 누락된 값을 대체할 방법을 결정합니다. 가능한 값은 "mean", "median", "most_frequent", "constant"입니다. 기본값은 "mean"입니다.
#
# 3. **fill_value**: `strategy="constant"`를 사용할 때 누락된 값을 대체하기 위한 상수 값을 설정합니다. 기본값은 `None`입니다. 이 값을 설정하면 모든 누락된 값을 해당 값으로 대체합니다.
#
# 4. **copy**: `True`인 경우, 원본 데이터는 변경되지 않고 새 데이터 배열이 생성됩니다. `False`일 경우, 원본 데이터가 대체됩니다. 기본값은 `True`입니다.
#
# 5. **add_indicator**: `True`인 경우, 누락된 값이 있는 특성에 대한 인디케이터(지시자) 변수가 결과에 추가됩니다. 기본값은 `False`입니다.
#
# ## `KNNImputer` 하이퍼파라미터:
#
# 1. **missing_values**: 누락된 값을 나타내는 placeholder입니다. `SimpleImputer`와 마찬가지로 기본값은 `np.nan`입니다.
#
# 2. **n_neighbors**: 누락된 값을 대체하는 데 사용할 가장 가까운 이웃의 수입니다. 기본값은 5입니다.
#
# 3. **weights**: 이웃을 가중치하는 방법입니다. 가능한 값은 "uniform", "distance" 또는 사용자 정의 함수입니다. "uniform"은 모든 이웃에게 동일한 가중치를, "distance"는 가까운 이웃에 더 높은 가중치를 부여합니다. 기본값은 "uniform"입니다.
#
# 4. **metric**: 거리 계산에 사용할 메트릭입니다. 기본값은 "nan_euclidean"으로, 유클리드 거리를 계산할 때 누락된 값이 있는 경우를 처리합니다.
#
# 5. **copy**: `True`인 경우, 원본 데이터는 변경되지 않고 새 데이터 배열이 생성됩니다. `False`일 경우, 원본 데이터가 변경됩니다. 기본값은 `True`입니다.
#
# 6. **add_indicator**: `True`인 경우, 누락된 값이 있는 특성에 대한 인디케이터(지시자) 변수가 결과에 추가됩니다. 기본값은 `False`입니다.
#
# 각각의 Imputer는 데이터 내의 누락된 값을 다루는 특정 전략에 따라 설정할 수 있으며, 해당 파라미터들을 통해 다양한 데이터 처리 전략을 적용할 수 있습니다.

# %% [markdown]
# ## `interpolate()` 메소드
#
# ### 1. `linear`
# - 기본값입니다.
# - 결측치를 양쪽의 값으로부터 선형적으로 추정합니다.
# - 시계열 데이터에서 일반적으로 사용되며, 데이터가 비교적 균일하게 분포할 때 적합합니다.
#
# ### 2. `time`
# - 시간 간격을 고려하여 선형적으로 보간합니다.
# - 시계열 데이터의 인덱스가 `DatetimeIndex`일 때 유용합니다.
#
# ### 3. `index`, `values`
# - 인덱스 값에 기반하여 선형적으로 보간합니다.
# - `index`는 인덱스 자체를, `values`는 인덱스의 값들을 기준으로 보간합니다.
#
# ### 4. `pad`, `ffill`
# - 앞 방향으로 이전의 유효한 값으로 결측치를 채웁니다.
#
# ### 5. `bfill`, `backfill`
# - 뒷 방향으로 다음의 유효한 값으로 결측치를 채웁니다.
#
# ### 6. `nearest`
# - 결측치에 가장 가까운 인덱스의 값으로 채웁니다.
#
# ### 7. `zero`, `slinear`, `quadratic`, `cubic`, `spline`
# - `spline`은 차수(order)를 지정할 수 있는데, 예를 들어 `order=2`는 이차 스플라인, `order=3`은 삼차 스플라인 보간을 의미합니다.
# - `zero`는 0차 스플라인(계단 함수), `slinear`는 선형, `quadratic`은 이차, `cubic`은 삼차 스플라인 보간입니다.
#
# ### 8. `polynomial`
# - 다항식 보간을 수행합니다. `order` 옵션으로 다항식의 차수를 지정해야 합니다.
#
# ### 9. `piecewise_polynomial`
# - 각 세그먼트에서 다항식 보간을 수행하는 조각별 다항식 보간법입니다.
#
# ### 10. `from_derivatives`
# - 미분 값으로부터 데이터를 보간합니다. 이 방법은 고급 사용자를 위한 것으로, 데이터의 미분값을 알고 있을 때 사용할 수 있습니다.
#
# ### 11. `akima`
# - Akima의 3차 스플라인 보간법을 사용합니다. 데이터 포인트 사이를 매끄럽게 연결하며, 국부적인 데이터 변동성에 민감하게 반응합니다.
#
# ### 12. `krogh`, `piecewise_polynomial`, `pchip`, `akima`, `cubicspline`
# - 각각 다른 종류의 스플라인 또는 다항식 기반 보간 방법입니다. 데이터의 특성과 필요에 따라 적절한 방법을 선택할 수 있습니다.
#
# `interpolate()` 메소드의 `method` 옵션을 사용할 때, 데이터의 특성과 보간에 대한 목적을 고려하여 적합한 방법을 선택하는 것이 중요합니다.

# %% [markdown]
# ---
# ---

# %%
import missingno as msno
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer

import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('bike_sharing_daily.csv')

# %%
df.isnull().sum()
# 결측치 존재
# Out:
# instant        0
# dteday         0
# season         0
# yr             0
# mnth           0
# holiday        0
# weekday        0
# workingday     0
# weathersit     0
# temp          17
# atemp         24
# hum           25
# windspeed     13
# casual        11
# registered    11
# cnt            0
# dtype: int64

# %%
msno.matrix(df)
# missingno로 결측값 시각적으로 볼 수 있음
# Out:
# <Axes: >

# %%
msno.bar(df)
# Out:
# <Axes: >

# %%
# 모든 결측값 제거
df.dropna()
# Out:
#      instant      dteday  season  yr  mnth  holiday  weekday  workingday  \
# 0          1  2011-01-01       1   0     1        0        6           0
# 1          2  2011-01-02       1   0     1        0        0           0
# 3          4  2011-01-04       1   0     1        0        2           1
# 4          5  2011-01-05       1   0     1        0        3           1
# 5          6  2011-01-06       1   0     1        0        4           1
# ..       ...         ...     ...  ..   ...      ...      ...         ...
# 723      724  2012-12-24       1   1    12        0        1           1
# 724      725  2012-12-25       1   1    12        1        2           0
# 726      727  2012-12-27       1   1    12        0        4           1
# 728      729  2012-12-29       1   1    12        0        6           0
# 730      731  2012-12-31       1   1    12        0        1           1
#
#      weathersit      temp     atemp       hum  windspeed  casual  registered  \
# 0             2  0.344167  0.363625  0.805833   0.160446   331.0       654.0
# 1             2  0.363478  0.353739  0.696087   0.248539   131.0       670.0
# 3             1  0.200000  0.212122  0.590435   0.160296   108.0      1454.0
# 4             1  0.226957  0.229270  0.436957   0.186900    82.0      1518.0
# 5             1  0.204348  0.233209  0.518261   0.089565    88.0      1518.0
# ..          ...       ...       ...       ...        ...     ...         ...
# 723           2  0.231304  0.258900  0.791304   0.077230   174.0       746.0
# 724           2  0.291304  0.294465  0.734783   0.168726   440.0       573.0
# 726           2  0.254167  0.226642  0.652917   0.350133   247.0      1867.0
# 728           2  0.253333  0.242400  0.752917   0.124383   159.0      1182.0
# 730           2  0.215833  0.223487  0.577500   0.154846   439.0      2290.0
#
#       cnt
# 0     985
# 1     801
# 3    1562
# 4    1600
# 5    1606
# ..    ...
# 723   920
# 724  1013
# 726  2114
# 728  1341
# 730  2729
#
# [634 rows x 16 columns]

# %%
# 결측값이 모든 칼럼의 결측값이 index로 다 인 경우, 행값이 다 na값이면 제거
df.dropna(how='all')
# Out:
#      instant      dteday  season  yr  mnth  holiday  weekday  workingday  \
# 0          1  2011-01-01       1   0     1        0        6           0
# 1          2  2011-01-02       1   0     1        0        0           0
# 2          3  2011-01-03       1   0     1        0        1           1
# 3          4  2011-01-04       1   0     1        0        2           1
# 4          5  2011-01-05       1   0     1        0        3           1
# ..       ...         ...     ...  ..   ...      ...      ...         ...
# 726      727  2012-12-27       1   1    12        0        4           1
# 727      728  2012-12-28       1   1    12        0        5           1
# 728      729  2012-12-29       1   1    12        0        6           0
# 729      730  2012-12-30       1   1    12        0        0           0
# 730      731  2012-12-31       1   1    12        0        1           1
#
#      weathersit      temp     atemp       hum  windspeed  casual  registered  \
# 0             2  0.344167  0.363625  0.805833   0.160446   331.0       654.0
# 1             2  0.363478  0.353739  0.696087   0.248539   131.0       670.0
# 2             1  0.196364       NaN  0.437273   0.248309   120.0      1229.0
# 3             1  0.200000  0.212122  0.590435   0.160296   108.0      1454.0
# 4             1  0.226957  0.229270  0.436957   0.186900    82.0      1518.0
# ..          ...       ...       ...       ...        ...     ...         ...
# 726           2  0.254167  0.226642  0.652917   0.350133   247.0      1867.0
# 727           2  0.253333       NaN  0.590000   0.155471   644.0      2451.0
# 728           2  0.253333  0.242400  0.752917   0.124383   159.0      1182.0
# 729           1       NaN  0.231700  0.483333   0.350754   364.0      1432.0
# 730           2  0.215833  0.223487  0.577500   0.154846   439.0      2290.0
#
#       cnt
# 0     985
# 1     801
# 2    1349
# 3    1562
# 4    1600
# ..    ...
# 726  2114
# 727  3095
# 728  1341
# 729  1796
# 730  2729
#
# [731 rows x 16 columns]

# %%
# 하나의 칼럼이라도 결측값이 있으면 그 행을 제외
df.dropna(how='any')
# Out:
#      instant      dteday  season  yr  mnth  holiday  weekday  workingday  \
# 0          1  2011-01-01       1   0     1        0        6           0
# 1          2  2011-01-02       1   0     1        0        0           0
# 3          4  2011-01-04       1   0     1        0        2           1
# 4          5  2011-01-05       1   0     1        0        3           1
# 5          6  2011-01-06       1   0     1        0        4           1
# ..       ...         ...     ...  ..   ...      ...      ...         ...
# 723      724  2012-12-24       1   1    12        0        1           1
# 724      725  2012-12-25       1   1    12        1        2           0
# 726      727  2012-12-27       1   1    12        0        4           1
# 728      729  2012-12-29       1   1    12        0        6           0
# 730      731  2012-12-31       1   1    12        0        1           1
#
#      weathersit      temp     atemp       hum  windspeed  casual  registered  \
# 0             2  0.344167  0.363625  0.805833   0.160446   331.0       654.0
# 1             2  0.363478  0.353739  0.696087   0.248539   131.0       670.0
# 3             1  0.200000  0.212122  0.590435   0.160296   108.0      1454.0
# 4             1  0.226957  0.229270  0.436957   0.186900    82.0      1518.0
# 5             1  0.204348  0.233209  0.518261   0.089565    88.0      1518.0
# ..          ...       ...       ...       ...        ...     ...         ...
# 723           2  0.231304  0.258900  0.791304   0.077230   174.0       746.0
# 724           2  0.291304  0.294465  0.734783   0.168726   440.0       573.0
# 726           2  0.254167  0.226642  0.652917   0.350133   247.0      1867.0
# 728           2  0.253333  0.242400  0.752917   0.124383   159.0      1182.0
# 730           2  0.215833  0.223487  0.577500   0.154846   439.0      2290.0
#
#       cnt
# 0     985
# 1     801
# 3    1562
# 4    1600
# 5    1606
# ..    ...
# 723   920
# 724  1013
# 726  2114
# 728  1341
# 730  2729
#
# [634 rows x 16 columns]

# %%
# x개 이상 등 컬럼의 개수에 따른 제거
df.dropna(thresh=1) # 하나라도 있으면 제거!
# Out:
#      instant      dteday  season  yr  mnth  holiday  weekday  workingday  \
# 0          1  2011-01-01       1   0     1        0        6           0
# 1          2  2011-01-02       1   0     1        0        0           0
# 2          3  2011-01-03       1   0     1        0        1           1
# 3          4  2011-01-04       1   0     1        0        2           1
# 4          5  2011-01-05       1   0     1        0        3           1
# ..       ...         ...     ...  ..   ...      ...      ...         ...
# 726      727  2012-12-27       1   1    12        0        4           1
# 727      728  2012-12-28       1   1    12        0        5           1
# 728      729  2012-12-29       1   1    12        0        6           0
# 729      730  2012-12-30       1   1    12        0        0           0
# 730      731  2012-12-31       1   1    12        0        1           1
#
#      weathersit      temp     atemp       hum  windspeed  casual  registered  \
# 0             2  0.344167  0.363625  0.805833   0.160446   331.0       654.0
# 1             2  0.363478  0.353739  0.696087   0.248539   131.0       670.0
# 2             1  0.196364       NaN  0.437273   0.248309   120.0      1229.0
# 3             1  0.200000  0.212122  0.590435   0.160296   108.0      1454.0
# 4             1  0.226957  0.229270  0.436957   0.186900    82.0      1518.0
# ..          ...       ...       ...       ...        ...     ...         ...
# 726           2  0.254167  0.226642  0.652917   0.350133   247.0      1867.0
# 727           2  0.253333       NaN  0.590000   0.155471   644.0      2451.0
# 728           2  0.253333  0.242400  0.752917   0.124383   159.0      1182.0
# 729           1       NaN  0.231700  0.483333   0.350754   364.0      1432.0
# 730           2  0.215833  0.223487  0.577500   0.154846   439.0      2290.0
#
#       cnt
# 0     985
# 1     801
# 2    1349
# 3    1562
# 4    1600
# ..    ...
# 726  2114
# 727  3095
# 728  1341
# 729  1796
# 730  2729
#
# [731 rows x 16 columns]

# %%
# 특정 칼럼을 지정할 때 subset
df.dropna(subset = ['atemp'])
# Out:
#      instant      dteday  season  yr  mnth  holiday  weekday  workingday  \
# 0          1  2011-01-01       1   0     1        0        6           0
# 1          2  2011-01-02       1   0     1        0        0           0
# 3          4  2011-01-04       1   0     1        0        2           1
# 4          5  2011-01-05       1   0     1        0        3           1
# 5          6  2011-01-06       1   0     1        0        4           1
# ..       ...         ...     ...  ..   ...      ...      ...         ...
# 725      726  2012-12-26       1   1    12        0        3           1
# 726      727  2012-12-27       1   1    12        0        4           1
# 728      729  2012-12-29       1   1    12        0        6           0
# 729      730  2012-12-30       1   1    12        0        0           0
# 730      731  2012-12-31       1   1    12        0        1           1
#
#      weathersit      temp     atemp       hum  windspeed  casual  registered  \
# 0             2  0.344167  0.363625  0.805833   0.160446   331.0       654.0
# 1             2  0.363478  0.353739  0.696087   0.248539   131.0       670.0
# 3             1  0.200000  0.212122  0.590435   0.160296   108.0      1454.0
# 4             1  0.226957  0.229270  0.436957   0.186900    82.0      1518.0
# 5             1  0.204348  0.233209  0.518261   0.089565    88.0      1518.0
# ..          ...       ...       ...       ...        ...     ...         ...
# 725           3  0.243333  0.220333  0.823333   0.316546     9.0         NaN
# 726           2  0.254167  0.226642  0.652917   0.350133   247.0      1867.0
# 728           2  0.253333  0.242400  0.752917   0.124383   159.0      1182.0
# 729           1       NaN  0.231700  0.483333   0.350754   364.0      1432.0
# 730           2  0.215833  0.223487  0.577500   0.154846   439.0      2290.0
#
#       cnt
# 0     985
# 1     801
# 3    1562
# 4    1600
# 5    1606
# ..    ...
# 725   441
# 726  2114
# 728  1341
# 729  1796
# 730  2729
#
# [707 rows x 16 columns]

# %%
# 대치방법들

df.fillna(0) # 단순하게 특정값 대치
df.fillna('0') # 단순하게 특정값 대치

df.fillna({'atemp':0}) # 특정 칼럼 지정 가능

df.fillna(df.atemp.mean()) # 변수화해서도 가능(이 경우, stemp의 평균값으로 채움)

df.fillna(np.mean(df.atemp)) # numpy와도 같이 조합해서 사용가능
# mean, max, min, median, std 등 모두 사용가능
# Out:
#      instant      dteday  season  yr  mnth  holiday  weekday  workingday  \
# 0          1  2011-01-01       1   0     1        0        6           0
# 1          2  2011-01-02       1   0     1        0        0           0
# 2          3  2011-01-03       1   0     1        0        1           1
# 3          4  2011-01-04       1   0     1        0        2           1
# 4          5  2011-01-05       1   0     1        0        3           1
# ..       ...         ...     ...  ..   ...      ...      ...         ...
# 726      727  2012-12-27       1   1    12        0        4           1
# 727      728  2012-12-28       1   1    12        0        5           1
# 728      729  2012-12-29       1   1    12        0        6           0
# 729      730  2012-12-30       1   1    12        0        0           0
# 730      731  2012-12-31       1   1    12        0        1           1
#
#      weathersit      temp     atemp       hum  windspeed  casual  registered  \
# 0             2  0.344167  0.363625  0.805833   0.160446   331.0       654.0
# 1             2  0.363478  0.353739  0.696087   0.248539   131.0       670.0
# 2             1  0.196364  0.474674  0.437273   0.248309   120.0      1229.0
# 3             1  0.200000  0.212122  0.590435   0.160296   108.0      1454.0
# 4             1  0.226957  0.229270  0.436957   0.186900    82.0      1518.0
# ..          ...       ...       ...       ...        ...     ...         ...
# 726           2  0.254167  0.226642  0.652917   0.350133   247.0      1867.0
# 727           2  0.253333  0.474674  0.590000   0.155471   644.0      2451.0
# 728           2  0.253333  0.242400  0.752917   0.124383   159.0      1182.0
# 729           1  0.474674  0.231700  0.483333   0.350754   364.0      1432.0
# 730           2  0.215833  0.223487  0.577500   0.154846   439.0      2290.0
#
#       cnt
# 0     985
# 1     801
# 2    1349
# 3    1562
# 4    1600
# ..    ...
# 726  2114
# 727  3095
# 728  1341
# 729  1796
# 730  2729
#
# [731 rows x 16 columns]

# %%
# 시계열 데이터의 경우

# 전의 데이터로 대치하는 경우
df.fillna(method='pad')

# 시점을 후의 시점에서 연속적으로 결측값이 발생하는 경우에, 한번만 대치
df.fillna(method='bfill')
df.fillna(method='bfill', limit=2) # n번 대치

# 보간법 - method를 다양히 넣을 수 있음
df.interpolate()
df.interpolate(method='values')
#df.interpolate(method='time') - 에러 발생. 시간에 따른 보간 위해서는 시계열 데이터로 인덱스 지정 필요
# Out:
#      instant      dteday  season  yr  mnth  holiday  weekday  workingday  \
# 0          1  2011-01-01       1   0     1        0        6           0
# 1          2  2011-01-02       1   0     1        0        0           0
# 2          3  2011-01-03       1   0     1        0        1           1
# 3          4  2011-01-04       1   0     1        0        2           1
# 4          5  2011-01-05       1   0     1        0        3           1
# ..       ...         ...     ...  ..   ...      ...      ...         ...
# 726      727  2012-12-27       1   1    12        0        4           1
# 727      728  2012-12-28       1   1    12        0        5           1
# 728      729  2012-12-29       1   1    12        0        6           0
# 729      730  2012-12-30       1   1    12        0        0           0
# 730      731  2012-12-31       1   1    12        0        1           1
#
#      weathersit      temp     atemp       hum  windspeed  casual  registered  \
# 0             2  0.344167  0.363625  0.805833   0.160446   331.0       654.0
# 1             2  0.363478  0.353739  0.696087   0.248539   131.0       670.0
# 2             1  0.196364  0.282931  0.437273   0.248309   120.0      1229.0
# 3             1  0.200000  0.212122  0.590435   0.160296   108.0      1454.0
# 4             1  0.226957  0.229270  0.436957   0.186900    82.0      1518.0
# ..          ...       ...       ...       ...        ...     ...         ...
# 726           2  0.254167  0.226642  0.652917   0.350133   247.0      1867.0
# 727           2  0.253333  0.234521  0.590000   0.155471   644.0      2451.0
# 728           2  0.253333  0.242400  0.752917   0.124383   159.0      1182.0
# 729           1  0.234583  0.231700  0.483333   0.350754   364.0      1432.0
# 730           2  0.215833  0.223487  0.577500   0.154846   439.0      2290.0
#
#       cnt
# 0     985
# 1     801
# 2    1349
# 3    1562
# 4    1600
# ..    ...
# 726  2114
# 727  3095
# 728  1341
# 729  1796
# 730  2729
#
# [731 rows x 16 columns]

# %%
# 시간에 따른 보간 위해서는 시계열데이터로 인덱스 지정필요
df_sp = df[['dteday','atemp']]

# %%
df_sp.info()
# dteday데이터는 object형으로 시계열 데이터가 아님
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 731 entries, 0 to 730
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   dteday  731 non-null    object
#  1   atemp   707 non-null    float64
# dtypes: float64(1), object(1)
# memory usage: 11.6+ KB

# %%
# 시계열 데이터로 만들기 위해서 pd.to_datetime
df_sp['dteday]'] = pd.to_datetime(df['dteday'])
# Out:
# C:\Users\01wkd\AppData\Local\Temp\ipykernel_16292\1107878335.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_sp['dteday]'] = pd.to_datetime(df['dteday'])

# %%
df_sp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 731 entries, 0 to 730
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   dteday   731 non-null    object
#  1   atemp    707 non-null    float64
#  2   dteday]  731 non-null    datetime64[ns]
# dtypes: datetime64[ns](1), float64(1), object(1)
# memory usage: 17.3+ KB

# %%
# 인덱스 지정 필요
df_sp = df_sp.set_index('dteday')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[57], line 2
#       1 # 인덱스 지정 필요
# ----> 2 df_sp = df_sp.set_index('dteday')
#
# File c:\Users\01wkd\anaconda3\Lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File c:\Users\01wkd\anaconda3\Lib\site-packages\pandas\core\frame.py:6012, in DataFrame.set_index(self, keys, drop, append, inplace, verify_integrity)
#    6009                 missing.append(col)
#    6011 if missing:
# -> 6012     raise KeyError(f"None of {missing} are in the columns")
#    6014 if inplace:
#    6015     frame = self
#
# KeyError: "None of ['dteday'] are in the columns"

# %%
df_sp.interpolate(method='time')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[55], line 1
# ----> 1 df_sp.interpolate(method='time')
#
# File c:\Users\01wkd\anaconda3\Lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File c:\Users\01wkd\anaconda3\Lib\site-packages\pandas\core\frame.py:11855, in DataFrame.interpolate(self, method, axis, limit, inplace, limit_direction, limit_area, downcast, **kwargs)
#   11843 @deprecate_nonkeyword_arguments(version=None, allowed_args=["self", "method"])
#   11844 def interpolate(
#   11845     self: DataFrame,
#    (...)
#   11853     **kwargs,
#   11854 ) -> DataFrame | None:
# > 11855     return super().interpolate(
#   11856         method,
#   11857         axis,
#   11858         limit,
#   11859         inplace,
#   11860         limit_direction,
#   11861         limit_area,
#   11862         downcast,
#   11863         **kwargs,
#   11864     )
#
# File c:\Users\01wkd\anaconda3\Lib\site-packages\pandas\core\generic.py:7568, in NDFrame.interpolate(self, method, axis, limit, inplace, limit_direction, limit_area, downcast, **kwargs)
#    7562 if isna(index).any():
#    7563     raise NotImplementedError(
#    7564         "Interpolation with NaNs in the index "
#    7565         "has not been implemented. Try filling "
#    7566         "those NaNs before interpolating."
#    7567     )
# -> 7568 new_data = obj._mgr.interpolate(
#    7569     method=method,
#    7570     axis=axis,
#    7571     index=index,
#    7572     limit=limit,
#    7573     limit_direction=limit_direction,
#    7574     limit_area=limit_area,
#    7575     inplace=inplace,
#    7576     downcast=downcast,
#    7577     **kwargs,
#    7578 )
#    7580 result = self._constructor(new_data)
#    7581 if should_transpose:
#
# File c:\Users\01wkd\anaconda3\Lib\site-packages\pandas\core\internals\managers.py:422, in BaseBlockManager.interpolate(self, **kwargs)
#     421 def interpolate(self: T, **kwargs) -> T:
# --> 422     return self.apply("interpolate", **kwargs)
#
# File c:\Users\01wkd\anaconda3\Lib\site-packages\pandas\core\internals\managers.py:352, in BaseBlockManager.apply(self, f, align_keys, ignore_failures, **kwargs)
#     350         applied = b.apply(f, **kwargs)
#     351     else:
# --> 352         applied = getattr(b, f)(**kwargs)
#     353 except (TypeError, NotImplementedError):
#     354     if not ignore_failures:
#
# File c:\Users\01wkd\anaconda3\Lib\site-packages\pandas\core\internals\blocks.py:1258, in Block.interpolate(self, method, axis, index, inplace, limit, limit_direction, limit_area, fill_value, downcast, **kwargs)
#    1255 data = self.values if inplace else self.values.copy()
#    1256 data = cast(np.ndarray, data)  # bc overridden by ExtensionBlock
# -> 1258 missing.interpolate_array_2d(
#    1259     data,
#    1260     method=method,
#    1261     axis=axis,
#    1262     index=index,
#    1263     limit=limit,
#    1264     limit_direction=limit_direction,
#    1265     limit_area=limit_area,
#    1266     fill_value=fill_value,
#    1267     **kwargs,
#    1268 )
#    1270 nb = self.make_block_same_class(data)
#    1271 return nb._maybe_downcast([nb], downcast)
#
# File c:\Users\01wkd\anaconda3\Lib\site-packages\pandas\core\missing.py:249, in interpolate_array_2d(data, method, axis, index, limit, limit_direction, limit_area, fill_value, coerce, downcast, **kwargs)
#     246 else:
#     247     assert index is not None  # for mypy
# --> 249     _interpolate_2d_with_fill(
#     250         data=data,
#     251         index=index,
#     252         axis=axis,
#     253         method=method,
#     254         limit=limit,
#     255         limit_direction=limit_direction,
#     256         limit_area=limit_area,
#     257         fill_value=fill_value,
#     258         **kwargs,
#     259     )
#     260 return
#
# File c:\Users\01wkd\anaconda3\Lib\site-packages\pandas\core\missing.py:292, in _interpolate_2d_with_fill(data, index, axis, method, limit, limit_direction, limit_area, fill_value, **kwargs)
#     290 if method == "time":
#     291     if not needs_i8_conversion(index.dtype):
# --> 292         raise ValueError(
#     293             "time-weighted interpolation only works "
#     294             "on Series or DataFrames with a "
#     295             "DatetimeIndex"
#     296         )
#     297     method = "values"
#     299 valid_limit_directions = ["forward", "backward", "both"]
#
# ValueError: time-weighted interpolation only works on Series or DataFrames with a DatetimeIndex

# %% [markdown]
# ### 우리가 배웠던 다양한 보간법을 통해 대치하고 난 후 회귀분석을 통해 평가하기

# %%
import seaborn as sns
mpg = sns.load_dataset('mpg')

# %%
mpg
#mpg는 연비
# cylinder 실린더 수
#displacement 배기량
#horsepower 마력
#weight 차량 무게
#acceleration 제로백
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    18.0          8         307.0       130.0    3504          12.0
# 1    15.0          8         350.0       165.0    3693          11.5
# 2    18.0          8         318.0       150.0    3436          11.0
# 3    16.0          8         304.0       150.0    3433          12.0
# 4    17.0          8         302.0       140.0    3449          10.5
# ..    ...        ...           ...         ...     ...           ...
# 393  27.0          4         140.0        86.0    2790          15.6
# 394  44.0          4          97.0        52.0    2130          24.6
# 395  32.0          4         135.0        84.0    2295          11.6
# 396  28.0          4         120.0        79.0    2625          18.6
# 397  31.0          4         119.0        82.0    2720          19.4
#
#      model_year  origin                       name
# 0            70     usa  chevrolet chevelle malibu
# 1            70     usa          buick skylark 320
# 2            70     usa         plymouth satellite
# 3            70     usa              amc rebel sst
# 4            70     usa                ford torino
# ..          ...     ...                        ...
# 393          82     usa            ford mustang gl
# 394          82  europe                  vw pickup
# 395          82     usa              dodge rampage
# 396          82     usa                ford ranger
# 397          82     usa                 chevy s-10
#
# [398 rows x 9 columns]

# %%
# 6개 결측치 모두 삭제
mpg.dropna(inplace=True)
mpg
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    18.0          8         307.0       130.0    3504          12.0
# 1    15.0          8         350.0       165.0    3693          11.5
# 2    18.0          8         318.0       150.0    3436          11.0
# 3    16.0          8         304.0       150.0    3433          12.0
# 4    17.0          8         302.0       140.0    3449          10.5
# ..    ...        ...           ...         ...     ...           ...
# 393  27.0          4         140.0        86.0    2790          15.6
# 394  44.0          4          97.0        52.0    2130          24.6
# 395  32.0          4         135.0        84.0    2295          11.6
# 396  28.0          4         120.0        79.0    2625          18.6
# 397  31.0          4         119.0        82.0    2720          19.4
#
#      model_year  origin                       name
# 0            70     usa  chevrolet chevelle malibu
# 1            70     usa          buick skylark 320
# 2            70     usa         plymouth satellite
# 3            70     usa              amc rebel sst
# 4            70     usa                ford torino
# ..          ...     ...                        ...
# 393          82     usa            ford mustang gl
# 394          82  europe                  vw pickup
# 395          82     usa              dodge rampage
# 396          82     usa                ford ranger
# 397          82     usa                 chevy s-10
#
# [392 rows x 9 columns]

# %%
df_x = mpg[['cylinders','displacement', 'horsepower', 'weight' ]]
df_x

# y값은 mpg
#실린더, 배기량, 마력이나, 무게에 따른 -> mpg차량의 연비를 예측
# Out:
#      cylinders  displacement  horsepower  weight
# 0            8         307.0       130.0    3504
# 1            8         350.0       165.0    3693
# 2            8         318.0       150.0    3436
# 3            8         304.0       150.0    3433
# 4            8         302.0       140.0    3449
# ..         ...           ...         ...     ...
# 393          4         140.0        86.0    2790
# 394          4          97.0        52.0    2130
# 395          4         135.0        84.0    2295
# 396          4         120.0        79.0    2625
# 397          4         119.0        82.0    2720
#
# [392 rows x 4 columns]

# %%
# 결측치 만들기
mrr = np.random.randint(0,392, size=20)

# %%
df_x.iloc[mrr] = np.nan

# %%
df_x.isna().sum()
# Out:
# cylinders       20
# displacement    20
# horsepower      20
# weight          20
# dtype: int64

# %%
# 다양한 결측치 사용해보기 위해 샘플데이터 만들기
df_sp = pd.concat([df_x, mpg['mpg']], axis=1)
df_sp1 = pd.concat([df_x, mpg['mpg']], axis=1)
df_sp2 = pd.concat([df_x, mpg['mpg']], axis=1)
df_sp3 = pd.concat([df_x, mpg['mpg']], axis=1)

# %% [markdown]
# - 평균으로 대치하기

# %%
df_x.cylinders.mean()
df_x.displacement.mean()
df_x.horsepower.mean()
df_x.weight.mean()
# Out:
# 2985.3844086021504

# %%
# df_sp 결측값을 단순평균으로 대치
df_sp['cylinders'] = df_sp['cylinders'].fillna(df_x.cylinders.mean())
df_sp['displacement'] = df_sp['displacement'].fillna(df_x.displacement.mean())
df_sp['horsepower'] = df_sp['horsepower'].fillna(df_x.horsepower.mean())
df_sp['weight'] = df_sp['weight'].fillna(df_x.weight.mean())

# %%
df_sp.isna().sum()
# Out:
# cylinders       0
# displacement    0
# horsepower      0
# weight          0
# mpg             0
# dtype: int64

# %% [markdown]
# ### 학습

# %%
# 학습을 위해 train_test_split
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(df_sp.drop('mpg', axis=1), df_sp['mpg'], test_size=0.3, random_state=111)

# %%
import statsmodels.api as sm
import matplotlib.pyplot as plt

# %%
# 회귀분석 진행
fit_train1 = sm.OLS(y_train, x_train)

# %%
# 회귀분석 모델 만들기
fit_train1 = fit_train1.fit()

# %%
# 실제값과 예측값을 통해 간단한 시각화 비교
plt.plot(np.array(fit_train1.predict(x_test)), label='pred')
plt.plot(np.array(y_test), label='True')
plt.legend()

# %%
# MSE
from sklearn.metrics import mean_squared_error

# 평균으로 대치했을 때 나온 MSE값 
mse1 = mean_squared_error(y_true = y_test, y_pred = fit_train1.predict(x_test))
print(mse1)
# Out:
# 56.80672145910194

# %% [markdown]
# ### 결측치를 0으로 대치

# %%
df_sp1.isnull().sum()
# Out:
# cylinders       20
# displacement    20
# horsepower      20
# weight          20
# mpg              0
# dtype: int64

# %%
# df_sp는 0으로 대치
df_sp1['cylinders'] = df_sp1['cylinders'].fillna(0)
df_sp1['displacement'] = df_sp1['displacement'].fillna(0)
df_sp1['horsepower'] = df_sp1['horsepower'].fillna(0)
df_sp1['weight'] = df_sp1['weight'].fillna(0)

# %%
df_sp1
# Out:
#      cylinders  displacement  horsepower  weight   mpg
# 0          8.0         307.0       130.0  3504.0  18.0
# 1          8.0         350.0       165.0  3693.0  15.0
# 2          8.0         318.0       150.0  3436.0  18.0
# 3          8.0         304.0       150.0  3433.0  16.0
# 4          8.0         302.0       140.0  3449.0  17.0
# ..         ...           ...         ...     ...   ...
# 393        4.0         140.0        86.0  2790.0  27.0
# 394        4.0          97.0        52.0  2130.0  44.0
# 395        4.0         135.0        84.0  2295.0  32.0
# 396        0.0           0.0         0.0     0.0  28.0
# 397        4.0         119.0        82.0  2720.0  31.0
#
# [392 rows x 5 columns]

# %% [markdown]
# ### 학습

# %%
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(df_sp1.drop('mpg', axis=1), df_sp1['mpg'], test_size=0.3, random_state=111)

# %%
# 회귀분석
fit_train2 = sm.OLS(y_train, x_train)

# %%
# 회귀분석 모델링
fit_train2 = fit_train2.fit()

# %%
# 실제값과 예측값을 통해 간단한 시각적 비교
plt.plot(np.array(fit_train2.predict(x_test)), label='pred')
plt.plot(np.array(y_test), label='True')
plt.legend()

# %%
# MSE
from sklearn.metrics import mean_squared_error

#0으로 대치했을 때 나온 MSE 
mse2 = mean_squared_error(y_true = y_test, y_pred = fit_train2.predict(x_test))
print(mse2)
# Out:
# 80.6109581498707

# %% [markdown]
# ### 선형보간법

# %%
df_sp2.isna().sum()
# Out:
# cylinders       20
# displacement    20
# horsepower      20
# weight          20
# mpg              0
# dtype: int64

# %%
#df_sp은 단순평균으로 대치
df_sp2['cylinders']=df_sp2['cylinders'].interpolate(method='linear')
df_sp2['displacement']=df_sp2['displacement'].interpolate(method='linear')
df_sp2['horsepower']=df_sp2['horsepower'].interpolate(method='linear')
df_sp2['weight']=df_sp2['weight'].interpolate(method='linear')

# %% [markdown]
# - 학습

# %%
## 학습을 하기 위해 train_test_split
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test =train_test_split(df_sp2.drop('mpg',axis=1), df_sp2['mpg'], test_size=0.3, random_state=111)

# %%
# 회귀분석
fit_train3 = sm.OLS(y_train, x_train)

# %%
# 회귀분석 모델링
fit_train3 = fit_train3.fit()

# %%
# 실제값과 예측값 시각화 비교
plt.plot(np.array(fit_train3.predict(x_test)), label='pred')
plt.plot(np.array(y_test), label='True')
plt.legend()

# %%
# MSE
from sklearn.metrics import mean_squared_error

#선형보간 대치했을 때 나온 MSE값
mse3 = mean_squared_error(y_true = y_test, y_pred = fit_train3.predict(x_test))
print(mse3)
# Out:
# 57.42747092563657

# %% [markdown]
# ---

# %%
print(f'평균대치\t: {mse1:.3f} \n0 대치\t\t: {mse2:.3f} \n선형보간\t: {mse3:.3f}')
# Out:
# 평균대치	: 56.807
# 0 대치		: 80.611
# 선형보간	: 57.427
